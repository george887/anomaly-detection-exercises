# %%
from __future__ import division
import itertools
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import pandas as pd
import math
from sklearn import metrics
from random import randint
from matplotlib import style
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Discrete Data + Probability
# - Use basic probability to identify anomalous request methods. You will want to make sure the text is normalized in order to reduce the noise.

# %% [markdown]
# # Wrangle and Acquire

# %%
colnames=['ip', 'timestamp', 'request_method', 'status', 'size',
          'destination', 'request_agent']
df_orig = pd.read_csv('http://python.zach.lol/access.log',          
                 engine='python',
                 header=None,
                 index_col=False,
                 names=colnames,
                 sep=r'\s(?=(?:[^"]*"[^"]*")*[^"]*$)(?![^\[]*\])',
                 na_values='"-"',
                 usecols=[0, 3, 4, 5, 6, 7, 8]
)

new = pd.DataFrame([["95.31.18.119", "[21/Apr/2019:10:02:41+0000]", 
                     "GET /api/v1/items/HTTP/1.1", 200, 1153005, np.nan, 
                     "python-requests/2.21.0"],
                    ["95.31.16.121", "[17/Apr/2019:19:36:41+0000]", 
                     "GET /api/v1/sales?page=79/HTTP/1.1", 301, 1005, np.nan, 
                     "python-requests/2.21.0"],
                    ["97.105.15.120", "[18/Apr/2019:19:42:41+0000]", 
                     "GET /api/v1/sales?page=79/HTTP/1.1", 301, 2560, np.nan, 
                     "python-requests/2.21.0"],
                    ["97.105.19.58", "[19/Apr/2019:19:42:41+0000]", 
                     "GET /api/v1/sales?page=79/HTTP/1.1", 200, 2056327, np.nan, 
                     "python-requests/2.21.0"]], columns=colnames)

df = df_orig.append(new)

# %%
df.head()
# Out:
#              ip                     timestamp  \
# 0  97.105.19.58  [16/Apr/2019:19:34:42 +0000]
# 1  97.105.19.58  [16/Apr/2019:19:34:42 +0000]
# 2  97.105.19.58  [16/Apr/2019:19:34:44 +0000]
# 3  97.105.19.58  [16/Apr/2019:19:34:46 +0000]
# 4  97.105.19.58  [16/Apr/2019:19:34:48 +0000]
#
#                          request_method  status    size destination  \
# 0  "GET /api/v1/sales?page=81 HTTP/1.1"     200  512495         NaN
# 1          "GET /api/v1/items HTTP/1.1"     200    3561         NaN
# 2  "GET /api/v1/sales?page=82 HTTP/1.1"     200  510103         NaN
# 3  "GET /api/v1/sales?page=83 HTTP/1.1"     200  510003         NaN
# 4  "GET /api/v1/sales?page=84 HTTP/1.1"     200  511963         NaN
#
#               request_agent
# 0  "python-requests/2.21.0"
# 1  "python-requests/2.21.0"
# 2  "python-requests/2.21.0"
# 3  "python-requests/2.21.0"
# 4  "python-requests/2.21.0"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13978 entries, 0 to 3
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ip              13978 non-null  object
#  1   timestamp       13978 non-null  object
#  2   request_method  13978 non-null  object
#  3   status          13978 non-null  int64
#  4   size            13978 non-null  int64
#  5   destination     25 non-null     object
#  6   request_agent   13978 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 873.6+ KB

# %% [markdown]
# # Parse Datetime:

# %%
df.timestamp = df.timestamp.str.replace(r'(\[|\])', '', regex=True)
df.timestamp= pd.to_datetime(df.timestamp.str.replace(':', ' ', 1)) 
df = df.set_index('timestamp')

# %%
df.destination.value_counts()
# Out:
# "https://python.zach.lol/"                                        4
# "https://ds.codeup.com/8.3_Acquire/"                              3
# "https://python.zach.lol/api/v1/"                                 2
# "https://python.zach.lol/api/v1/stores?page=1"                    2
# "http://localhost:8888/notebooks/acquire.ipynb"                   1
# "https://python.zach.lol/api/v1/stores?page=0"                    1
# "https://python.zach.lol/api/v1/sales?page=3"                     1
# "https://python.zach.lol/api/V1/HiZach!"                          1
# "http://localhost:8889/notebooks/timeseries_acquisition.ipynb"    1
# "https://python.zach.lol/api/v1//api/v1/items?page=2"             1
# "https://python.zach.lol/api/v1/stores?page=2"                    1
# "https://python.zach.lol/api/v1/I_DIDNT_DO_IT!!!!"                1
# "https://python.zach.lol/api/v1/items"                            1
# "https://python.zach.lol/api/v1//api/v1/items"                    1
# "https://python.zach.lol/api/v1/items?page=0"                     1
# "https://python.zach.lol/api/v1/helloclass!"                      1
# "https://python.zach.lol/api/v1//api/v1/items/next_page"          1
# "https://python.zach.lol/api/v1/stores?page=999"                  1
# Name: destination, dtype: int64

# %% [markdown]
# # Clean up text

# %%
for col in ['request_method', 'request_agent', 'destination']:
    df[col] = df[col].str.replace('"', '')

df.head()
# Out:
#                                      ip                      request_method  \
# timestamp
# 2019-04-16 19:34:42+00:00  97.105.19.58  GET /api/v1/sales?page=81 HTTP/1.1
# 2019-04-16 19:34:42+00:00  97.105.19.58          GET /api/v1/items HTTP/1.1
# 2019-04-16 19:34:44+00:00  97.105.19.58  GET /api/v1/sales?page=82 HTTP/1.1
# 2019-04-16 19:34:46+00:00  97.105.19.58  GET /api/v1/sales?page=83 HTTP/1.1
# 2019-04-16 19:34:48+00:00  97.105.19.58  GET /api/v1/sales?page=84 HTTP/1.1
#
#                            status    size destination           request_agent
# timestamp
# 2019-04-16 19:34:42+00:00     200  512495         NaN  python-requests/2.21.0
# 2019-04-16 19:34:42+00:00     200    3561         NaN  python-requests/2.21.0
# 2019-04-16 19:34:44+00:00     200  510103         NaN  python-requests/2.21.0
# 2019-04-16 19:34:46+00:00     200  510003         NaN  python-requests/2.21.0
# 2019-04-16 19:34:48+00:00     200  511963         NaN  python-requests/2.21.0

# %%
# Removes the detail of the page number
df['request_method'] = df.request_method.str.replace(r'\?page=[0-9]+', '', regex=True)

df.head()
# Out:
#                                      ip              request_method  status  \
# timestamp
# 2019-04-16 19:34:42+00:00  97.105.19.58  GET /api/v1/sales HTTP/1.1     200
# 2019-04-16 19:34:42+00:00  97.105.19.58  GET /api/v1/items HTTP/1.1     200
# 2019-04-16 19:34:44+00:00  97.105.19.58  GET /api/v1/sales HTTP/1.1     200
# 2019-04-16 19:34:46+00:00  97.105.19.58  GET /api/v1/sales HTTP/1.1     200
# 2019-04-16 19:34:48+00:00  97.105.19.58  GET /api/v1/sales HTTP/1.1     200
#
#                              size destination           request_agent
# timestamp
# 2019-04-16 19:34:42+00:00  512495         NaN  python-requests/2.21.0
# 2019-04-16 19:34:42+00:00    3561         NaN  python-requests/2.21.0
# 2019-04-16 19:34:44+00:00  510103         NaN  python-requests/2.21.0
# 2019-04-16 19:34:46+00:00  510003         NaN  python-requests/2.21.0
# 2019-04-16 19:34:48+00:00  511963         NaN  python-requests/2.21.0

# %% [markdown]
# # Add Variable - Converting bytes to mb:

# %%
df['size_mb'] = [n/1024/1024 for n in df['size']]

# %% [markdown]
# # Detecting Anomalies in Discrete Variables
# ## Finding anomalies in already existing data:
# **We can easily see some anomalies around IP addresses.**

# %%
ip_df = pd.DataFrame(df.ip.value_counts(dropna=False)).reset_index().\
                rename(index=str, columns={'index': 'ip', 'ip': 'ip_count'})
ip_df2 = pd.DataFrame(df.ip.value_counts(dropna=False)/df.ip.count()).reset_index().\
                rename(index=str, columns={'index': 'ip', 'ip': 'ip_proba'})
ip_df = ip_df.merge(ip_df2)


# see those where rate < 1% 
ip_df[ip_df.ip_proba < .01]
# Out:
#                 ip  ip_count  ip_proba
# 4   68.201.219.223        21  0.001502
# 5      24.26.242.9        21  0.001502
# 6    52.87.230.102         2  0.000143
# 7    70.121.214.34         2  0.000143
# 8   35.175.171.137         2  0.000143
# 9    34.207.64.242         1  0.000072
# 10    45.23.250.16         1  0.000072
# 11   52.90.165.200         1  0.000072
# 12    52.91.30.150         1  0.000072
# 13   54.172.14.223         1  0.000072
# 14    95.31.18.119         1  0.000072
# 15    35.174.209.2         1  0.000072
# 16   97.105.15.120         1  0.000072
# 17   34.229.70.250         1  0.000072
# 18    95.31.16.121         1  0.000072
# 19    3.88.129.158         1  0.000072
# 20    3.92.201.136         1  0.000072
# 21   54.145.52.184         1  0.000072

# %%
# Shows the data to be unbalanced
ip_df.sort_values(by='ip_proba', ascending=False).head()
# Out:
#                ip  ip_count  ip_proba
# 0    97.105.19.58     11999  0.858420
# 1  173.173.113.51      1059  0.075762
# 2  72.181.113.170       613  0.043855
# 3   72.181.105.81       246  0.017599
# 4  68.201.219.223        21  0.001502

# %%
print(len(ip_df))

print(ip_df.tail(10))

plt.figure(figsize=(12, 4))
splot = sns.barplot(data=ip_df, x = 'ip', y = 'ip_count', ci = None)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', xytext = (0, 10), 
                   textcoords = 'offset points'
                   )
    plt.xticks(rotation='vertical')
# Out:
# 22
#                ip  ip_count  ip_proba
# 12   52.91.30.150         1  0.000072
# 13  54.172.14.223         1  0.000072
# 14   95.31.18.119         1  0.000072
# 15   35.174.209.2         1  0.000072
# 16  97.105.15.120         1  0.000072
# 17  34.229.70.250         1  0.000072
# 18   95.31.16.121         1  0.000072
# 19   3.88.129.158         1  0.000072
# 20   3.92.201.136         1  0.000072
# 21  54.145.52.184         1  0.000072

# %% [markdown]
# # Detecting anomalies by establishing a baseline and evaluate as new data arrives.
# ## Establish a baseline

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 13978 entries, 2019-04-16 19:34:42+00:00 to 2019-04-19 19:42:41+00:00
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ip              13978 non-null  object
#  1   request_method  13978 non-null  object
#  2   status          13978 non-null  int64
#  3   size            13978 non-null  int64
#  4   destination     25 non-null     object
#  5   request_agent   13978 non-null  object
#  6   size_mb         13978 non-null  float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 873.6+ KB

# %%
df.head()
# Out:
#                                      ip              request_method  status  \
# timestamp
# 2019-04-16 19:34:42+00:00  97.105.19.58  GET /api/v1/sales HTTP/1.1     200
# 2019-04-16 19:34:42+00:00  97.105.19.58  GET /api/v1/items HTTP/1.1     200
# 2019-04-16 19:34:44+00:00  97.105.19.58  GET /api/v1/sales HTTP/1.1     200
# 2019-04-16 19:34:46+00:00  97.105.19.58  GET /api/v1/sales HTTP/1.1     200
# 2019-04-16 19:34:48+00:00  97.105.19.58  GET /api/v1/sales HTTP/1.1     200
#
#                              size destination           request_agent  \
# timestamp
# 2019-04-16 19:34:42+00:00  512495         NaN  python-requests/2.21.0
# 2019-04-16 19:34:42+00:00    3561         NaN  python-requests/2.21.0
# 2019-04-16 19:34:44+00:00  510103         NaN  python-requests/2.21.0
# 2019-04-16 19:34:46+00:00  510003         NaN  python-requests/2.21.0
# 2019-04-16 19:34:48+00:00  511963         NaN  python-requests/2.21.0
#
#                             size_mb
# timestamp
# 2019-04-16 19:34:42+00:00  0.488753
# 2019-04-16 19:34:42+00:00  0.003396
# 2019-04-16 19:34:44+00:00  0.486472
# 2019-04-16 19:34:46+00:00  0.486377
# 2019-04-16 19:34:48+00:00  0.488246

# %%
df.index.dtype
# Out:
# datetime64[ns, UTC]

# %%
pd.__version__
# Out:
# '1.1.3'

# %%
train = df.loc['2019-04-16 19:34:42':'2019-04-17 12:55:14']
train = train[['ip','request_method','status','size','destination','request_agent','size_mb']]

# %% [markdown]
# # Compute probabilities based on train sample:

# %%
ip_df = pd.DataFrame(train.ip.value_counts(dropna=False)/train.ip.count()).reset_index().\
                rename(index=str, columns={'index': 'ip', 'ip': 'ip_proba'})
ip_df.head()
# Out:
#                ip  ip_proba
# 0    97.105.19.58  0.858595
# 1  173.173.113.51  0.075784
# 2  72.181.113.170  0.043867
# 3   72.181.105.81  0.017604
# 4     24.26.242.9  0.001503

# %% [markdown]
# ## Merge probabilities with all data (train + new data):
# Where the IP address is new, i.e. not seen in the training dataset, fill the probability with a value of 0.

# %%
df = df.reset_index().merge(ip_df, on=['ip'], how='left').fillna(value=0).set_index('timestamp')
df.ip_proba.value_counts()
# Out:
# 0.858595    11999
# 0.075784     1059
# 0.043867      613
# 0.017604      246
# 0.001503       42
# 0.000072       10
# 0.000143        6
# 0.000000        3
# Name: ip_proba, dtype: int64

# %%
df.head()
# Out:
#                                      ip              request_method  status  \
# timestamp
# 2019-04-16 19:34:42+00:00  97.105.19.58  GET /api/v1/sales HTTP/1.1     200
# 2019-04-16 19:34:42+00:00  97.105.19.58  GET /api/v1/items HTTP/1.1     200
# 2019-04-16 19:34:44+00:00  97.105.19.58  GET /api/v1/sales HTTP/1.1     200
# 2019-04-16 19:34:46+00:00  97.105.19.58  GET /api/v1/sales HTTP/1.1     200
# 2019-04-16 19:34:48+00:00  97.105.19.58  GET /api/v1/sales HTTP/1.1     200
#
#                              size destination           request_agent  \
# timestamp
# 2019-04-16 19:34:42+00:00  512495           0  python-requests/2.21.0
# 2019-04-16 19:34:42+00:00    3561           0  python-requests/2.21.0
# 2019-04-16 19:34:44+00:00  510103           0  python-requests/2.21.0
# 2019-04-16 19:34:46+00:00  510003           0  python-requests/2.21.0
# 2019-04-16 19:34:48+00:00  511963           0  python-requests/2.21.0
#
#                             size_mb  ip_proba
# timestamp
# 2019-04-16 19:34:42+00:00  0.488753  0.858595
# 2019-04-16 19:34:42+00:00  0.003396  0.858595
# 2019-04-16 19:34:44+00:00  0.486472  0.858595
# 2019-04-16 19:34:46+00:00  0.486377  0.858595
# 2019-04-16 19:34:48+00:00  0.488246  0.858595

# %% [markdown]
# # Conditional Probabilities: Probabilities using 2 discrete variables
# ## Probability of Status given IP Address:
# ### If we are looking for an unexpected status (like authentication failure) from a known/common IP address.¶

# %%
ip_probs = train.groupby('ip').size().div(len(df))

status_given_ip = pd.DataFrame(train.groupby(['ip', 'status']).\
                               size().div(len(train)).\
                               div(ip_probs, 
                                   axis=0, 
                                   level='ip').\
                               reset_index().\
                               rename(index=str, 
                                      columns={0: 'proba_status_given_ip'})
                              )
status_given_ip
# Out:
#                 ip  status  proba_status_given_ip
# 0   173.173.113.51     200               1.000286
# 1      24.26.242.9     200               1.000286
# 2     3.88.129.158     200               1.000286
# 3     3.92.201.136     200               1.000286
# 4    34.207.64.242     200               1.000286
# 5    34.229.70.250     200               1.000286
# 6     35.174.209.2     200               1.000286
# 7   35.175.171.137     200               1.000286
# 8     45.23.250.16     200               1.000286
# 9    52.87.230.102     200               1.000286
# 10   52.90.165.200     200               1.000286
# 11    52.91.30.150     200               1.000286
# 12   54.145.52.184     200               1.000286
# 13   54.172.14.223     200               1.000286
# 14  68.201.219.223     200               1.000286
# 15   70.121.214.34     200               1.000286
# 16   72.181.105.81     200               1.000286
# 17  72.181.113.170     200               0.997023
# 18  72.181.113.170     499               0.003264
# 19    97.105.19.58     200               0.999119
# 20    97.105.19.58     499               0.001167

# %%
ip_status_count = pd.DataFrame(train.groupby(['ip', 'status'])['request_method'].\
                                count().reset_index().\
                                rename(index=str, 
                                       columns={'request_method': 'ip_status_count'}))


ip_status = status_given_ip.merge(ip_status_count)
ip_status.sort_values(by="ip_status_count", ascending=False)
# Out:
#                 ip  status  proba_status_given_ip  ip_status_count
# 19    97.105.19.58     200               0.999119            11984
# 0   173.173.113.51     200               1.000286             1059
# 17  72.181.113.170     200               0.997023              611
# 16   72.181.105.81     200               1.000286              246
# 1      24.26.242.9     200               1.000286               21
# 14  68.201.219.223     200               1.000286               21
# 20    97.105.19.58     499               0.001167               14
# 7   35.175.171.137     200               1.000286                2
# 9    52.87.230.102     200               1.000286                2
# 15   70.121.214.34     200               1.000286                2
# 18  72.181.113.170     499               0.003264                2
# 8     45.23.250.16     200               1.000286                1
# 6     35.174.209.2     200               1.000286                1
# 11    52.91.30.150     200               1.000286                1
# 12   54.145.52.184     200               1.000286                1
# 13   54.172.14.223     200               1.000286                1
# 5    34.229.70.250     200               1.000286                1
# 4    34.207.64.242     200               1.000286                1
# 3     3.92.201.136     200               1.000286                1
# 2     3.88.129.158     200               1.000286                1
# 10   52.90.165.200     200               1.000286                1

# %% [markdown]
# **Add these probabilities to original events to detect anomalous events:**

# %%
df = df.reset_index().merge(ip_status, on=['ip', 'status'], how='left').fillna(value=0).set_index('timestamp')

# %%
df.head()
# Out:
#                                      ip              request_method  status  \
# timestamp
# 2019-04-16 19:34:42+00:00  97.105.19.58  GET /api/v1/sales HTTP/1.1     200
# 2019-04-16 19:34:42+00:00  97.105.19.58  GET /api/v1/items HTTP/1.1     200
# 2019-04-16 19:34:44+00:00  97.105.19.58  GET /api/v1/sales HTTP/1.1     200
# 2019-04-16 19:34:46+00:00  97.105.19.58  GET /api/v1/sales HTTP/1.1     200
# 2019-04-16 19:34:48+00:00  97.105.19.58  GET /api/v1/sales HTTP/1.1     200
#
#                              size destination           request_agent  \
# timestamp
# 2019-04-16 19:34:42+00:00  512495           0  python-requests/2.21.0
# 2019-04-16 19:34:42+00:00    3561           0  python-requests/2.21.0
# 2019-04-16 19:34:44+00:00  510103           0  python-requests/2.21.0
# 2019-04-16 19:34:46+00:00  510003           0  python-requests/2.21.0
# 2019-04-16 19:34:48+00:00  511963           0  python-requests/2.21.0
#
#                             size_mb  ip_proba  proba_status_given_ip  \
# timestamp
# 2019-04-16 19:34:42+00:00  0.488753  0.858595               0.999119
# 2019-04-16 19:34:42+00:00  0.003396  0.858595               0.999119
# 2019-04-16 19:34:44+00:00  0.486472  0.858595               0.999119
# 2019-04-16 19:34:46+00:00  0.486377  0.858595               0.999119
# 2019-04-16 19:34:48+00:00  0.488246  0.858595               0.999119
#
#                            ip_status_count
# timestamp
# 2019-04-16 19:34:42+00:00          11984.0
# 2019-04-16 19:34:42+00:00          11984.0
# 2019-04-16 19:34:44+00:00          11984.0
# 2019-04-16 19:34:46+00:00          11984.0
# 2019-04-16 19:34:48+00:00          11984.0

# %%
plt.title("Probability of Seeing a status given an IP by probability of seeing that IP address")
plt.xlabel("Probability of seeing the status given the IP")
plt.ylabel("Probabiliy of seeing this given IP address")
plt.scatter(df.proba_status_given_ip, df.ip_proba)

# %%
from sklearn.model_selection import train_test_split

# %%
train_validate, test = train_test_split(df, test_size=.2, random_state=123)

train, validate = train_test_split(train_validate, test_size=.3, random_state=123)

# %%
train.head()
# Out:
#                                        ip               request_method  \
# timestamp
# 2019-04-16 22:38:17+00:00    97.105.19.58   GET /api/v1/sales HTTP/1.1
# 2019-04-16 21:09:31+00:00    97.105.19.58   GET /api/v1/sales HTTP/1.1
# 2019-04-17 04:11:16+00:00  173.173.113.51  GET /api/v1/stores HTTP/1.1
# 2019-04-16 19:49:43+00:00    97.105.19.58    GET /favicon.ico HTTP/1.1
# 2019-04-16 19:54:58+00:00    97.105.19.58   GET /api/v1/sales HTTP/1.1
#
#                            status    size  \
# timestamp
# 2019-04-16 22:38:17+00:00     200  510084
# 2019-04-16 21:09:31+00:00     200  510082
# 2019-04-17 04:11:16+00:00     200    1328
# 2019-04-16 19:49:43+00:00     200     162
# 2019-04-16 19:54:58+00:00     200  494819
#
#                                                                  destination  \
# timestamp
# 2019-04-16 22:38:17+00:00                                                  0
# 2019-04-16 21:09:31+00:00                                                  0
# 2019-04-17 04:11:16+00:00                                                  0
# 2019-04-16 19:49:43+00:00  https://python.zach.lol/api/v1//api/v1/items?p...
# 2019-04-16 19:54:58+00:00                                                  0
#
#                                                                request_agent  \
# timestamp
# 2019-04-16 22:38:17+00:00                             python-requests/2.21.0
# 2019-04-16 21:09:31+00:00                             python-requests/2.21.0
# 2019-04-17 04:11:16+00:00                             python-requests/2.21.0
# 2019-04-16 19:49:43+00:00  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 19:54:58+00:00                             python-requests/2.20.1
#
#                             size_mb  ip_proba  proba_status_given_ip  \
# timestamp
# 2019-04-16 22:38:17+00:00  0.486454  0.858595               0.999119
# 2019-04-16 21:09:31+00:00  0.486452  0.858595               0.999119
# 2019-04-17 04:11:16+00:00  0.001266  0.075784               1.000286
# 2019-04-16 19:49:43+00:00  0.000154  0.858595               0.999119
# 2019-04-16 19:54:58+00:00  0.471896  0.858595               0.999119
#
#                            ip_status_count
# timestamp
# 2019-04-16 22:38:17+00:00          11984.0
# 2019-04-16 21:09:31+00:00          11984.0
# 2019-04-17 04:11:16+00:00           1059.0
# 2019-04-16 19:49:43+00:00          11984.0
# 2019-04-16 19:54:58+00:00          11984.0

# %%
train.request_method.value_counts()
# Out:
# GET /api/v1/sales HTTP/1.1                 6953
# GET /api/v1/items HTTP/1.1                  611
# GET /api/v1/stores HTTP/1.1                 114
# GET /documentation HTTP/1.1                  56
# GET / HTTP/1.1                               55
# GET /favicon.ico HTTP/1.1                    12
# GET /api/v1//api/v1/items HTTP/1.1            6
# GET /api/v1/items/api/v1/items HTTP/1.1       4
# GET /api/v1/ HTTP/1.1                         3
# GET /api/v1/store HTTP/1.1                    2
# GET /api/v1/sales/HTTP/1.1                    2
# GET /api/v1/items/next_page HTTP/1.1          2
# GET /api/v1/items&page=0 HTTP/1.1             1
# GET /api/V1/HiZach! HTTP/1.1                  1
# GET /api/v1/sales/ HTTP/1.1                   1
# GET /api/v1/helloclass! HTTP/1.1              1
# GET /api/v1/itemsitems HTTP/1.1               1
# GET /api/v1/I_DIDNT_DO_IT!!!! HTTP/1.1        1
# GET /api/v1items HTTP/1.1                     1
# Name: request_method, dtype: int64

# %%
req_meth_df = pd.DataFrame(train.request_method.value_counts(dropna=False)/train.request_method.count()).reset_index().\
                rename(index=str, columns={'index': 'request_method', 'request_method': 'req_meth_proba'})
req_meth_df.head()
# Out:
#                 request_method  req_meth_proba
# 0   GET /api/v1/sales HTTP/1.1        0.888335
# 1   GET /api/v1/items HTTP/1.1        0.078063
# 2  GET /api/v1/stores HTTP/1.1        0.014565
# 3  GET /documentation HTTP/1.1        0.007155
# 4               GET / HTTP/1.1        0.007027

# %%
train = train.reset_index().merge(req_meth_df, on=['request_method'], how='left').fillna(value=0).set_index('timestamp')
train.req_meth_proba.value_counts()
# Out:
# 0.888335    6953
# 0.078063     611
# 0.014565     114
# 0.007155      56
# 0.007027      55
# 0.001533      12
# 0.000128       7
# 0.000767       6
# 0.000256       6
# 0.000511       4
# 0.000383       3
# Name: req_meth_proba, dtype: int64

# %%
req_meth_probs = train.groupby('request_method').size().div(len(train))

# %%
req_meth_probs
# Out:
# request_method
# GET / HTTP/1.1                             0.007027
# GET /api/V1/HiZach! HTTP/1.1               0.000128
# GET /api/v1/ HTTP/1.1                      0.000383
# GET /api/v1//api/v1/items HTTP/1.1         0.000767
# GET /api/v1/I_DIDNT_DO_IT!!!! HTTP/1.1     0.000128
# GET /api/v1/helloclass! HTTP/1.1           0.000128
# GET /api/v1/items HTTP/1.1                 0.078063
# GET /api/v1/items&page=0 HTTP/1.1          0.000128
# GET /api/v1/items/api/v1/items HTTP/1.1    0.000511
# GET /api/v1/items/next_page HTTP/1.1       0.000256
# GET /api/v1/itemsitems HTTP/1.1            0.000128
# GET /api/v1/sales HTTP/1.1                 0.888335
# GET /api/v1/sales/ HTTP/1.1                0.000128
# GET /api/v1/sales/HTTP/1.1                 0.000256
# GET /api/v1/store HTTP/1.1                 0.000256
# GET /api/v1/stores HTTP/1.1                0.014565
# GET /api/v1items HTTP/1.1                  0.000128
# GET /documentation HTTP/1.1                0.007155
# GET /favicon.ico HTTP/1.1                  0.001533
# dtype: float64

# %%
status_given_req_meth = pd.DataFrame(train.groupby(['request_method', 'ip']).\
                               size().div(len(train)).\
                               div(req_meth_probs, 
                                   axis=0, 
                                   level='request_method').\
                               reset_index().\
                               rename(index=str, 
                                      columns={0: 'proba_status_given_req_meth'})
                              )
status_given_req_meth
# Out:
#                              request_method              ip  \
# 0                            GET / HTTP/1.1  35.175.171.137
# 1                            GET / HTTP/1.1  68.201.219.223
# 2                            GET / HTTP/1.1   70.121.214.34
# 3                            GET / HTTP/1.1   72.181.105.81
# 4                            GET / HTTP/1.1    97.105.19.58
# 5              GET /api/V1/HiZach! HTTP/1.1    97.105.19.58
# 6                     GET /api/v1/ HTTP/1.1   54.172.14.223
# 7                     GET /api/v1/ HTTP/1.1   72.181.105.81
# 8                     GET /api/v1/ HTTP/1.1    97.105.19.58
# 9        GET /api/v1//api/v1/items HTTP/1.1    97.105.19.58
# 10   GET /api/v1/I_DIDNT_DO_IT!!!! HTTP/1.1    97.105.19.58
# 11         GET /api/v1/helloclass! HTTP/1.1    97.105.19.58
# 12               GET /api/v1/items HTTP/1.1  173.173.113.51
# 13               GET /api/v1/items HTTP/1.1     24.26.242.9
# 14               GET /api/v1/items HTTP/1.1  35.175.171.137
# 15               GET /api/v1/items HTTP/1.1  68.201.219.223
# 16               GET /api/v1/items HTTP/1.1   72.181.105.81
# 17               GET /api/v1/items HTTP/1.1  72.181.113.170
# 18               GET /api/v1/items HTTP/1.1    97.105.19.58
# 19        GET /api/v1/items&page=0 HTTP/1.1    97.105.19.58
# 20  GET /api/v1/items/api/v1/items HTTP/1.1  68.201.219.223
# 21  GET /api/v1/items/api/v1/items HTTP/1.1    97.105.19.58
# 22     GET /api/v1/items/next_page HTTP/1.1    97.105.19.58
# 23          GET /api/v1/itemsitems HTTP/1.1    97.105.19.58
# 24               GET /api/v1/sales HTTP/1.1  173.173.113.51
# 25               GET /api/v1/sales HTTP/1.1     24.26.242.9
# 26               GET /api/v1/sales HTTP/1.1   72.181.105.81
# 27               GET /api/v1/sales HTTP/1.1  72.181.113.170
# 28               GET /api/v1/sales HTTP/1.1    97.105.19.58
# 29              GET /api/v1/sales/ HTTP/1.1    97.105.19.58
# 30               GET /api/v1/sales/HTTP/1.1   97.105.15.120
# 31               GET /api/v1/sales/HTTP/1.1    97.105.19.58
# 32               GET /api/v1/store HTTP/1.1    97.105.19.58
# 33              GET /api/v1/stores HTTP/1.1  173.173.113.51
# 34              GET /api/v1/stores HTTP/1.1     24.26.242.9
# 35              GET /api/v1/stores HTTP/1.1   72.181.105.81
# 36              GET /api/v1/stores HTTP/1.1  72.181.113.170
# 37              GET /api/v1/stores HTTP/1.1    97.105.19.58
# 38                GET /api/v1items HTTP/1.1   72.181.105.81
# 39              GET /documentation HTTP/1.1  68.201.219.223
# 40              GET /documentation HTTP/1.1   72.181.105.81
# 41              GET /documentation HTTP/1.1    97.105.19.58
# 42                GET /favicon.ico HTTP/1.1    35.174.209.2
# 43                GET /favicon.ico HTTP/1.1   52.90.165.200
# 44                GET /favicon.ico HTTP/1.1   54.145.52.184
# 45                GET /favicon.ico HTTP/1.1   72.181.105.81
# 46                GET /favicon.ico HTTP/1.1  72.181.113.170
# 47                GET /favicon.ico HTTP/1.1    97.105.19.58
#
#     proba_status_given_req_meth
# 0                      0.018182
# 1                      0.036364
# 2                      0.018182
# 3                      0.054545
# 4                      0.872727
# 5                      1.000000
# 6                      0.333333
# 7                      0.333333
# 8                      0.333333
# 9                      1.000000
# 10                     1.000000
# 11                     1.000000
# 12                     0.188216
# 13                     0.006547
# 14                     0.001637
# 15                     0.014730
# 16                     0.049100
# 17                     0.090016
# 18                     0.649755
# 19                     1.000000
# 20                     0.250000
# 21                     0.750000
# 22                     1.000000
# 23                     1.000000
# 24                     0.065152
# 25                     0.000863
# 26                     0.013376
# 27                     0.041852
# 28                     0.878757
# 29                     1.000000
# 30                     0.500000
# 31                     0.500000
# 32                     1.000000
# 33                     0.228070
# 34                     0.043860
# 35                     0.026316
# 36                     0.008772
# 37                     0.692982
# 38                     1.000000
# 39                     0.017857
# 40                     0.017857
# 41                     0.964286
# 42                     0.083333
# 43                     0.083333
# 44                     0.083333
# 45                     0.166667
# 46                     0.083333
# 47                     0.500000

# %%
req_meth_count = pd.DataFrame(train.groupby(['request_method', 'ip'])['status'].\
                                count().reset_index().\
                                rename(index=str, 
                                       columns={'status': 'req_meth_count'}))


req_meth_ip = status_given_req_meth.merge(req_meth_count)
req_meth_ip.sort_values(by="req_meth_count", ascending=False)
# Out:
#                              request_method              ip  \
# 28               GET /api/v1/sales HTTP/1.1    97.105.19.58
# 24               GET /api/v1/sales HTTP/1.1  173.173.113.51
# 18               GET /api/v1/items HTTP/1.1    97.105.19.58
# 27               GET /api/v1/sales HTTP/1.1  72.181.113.170
# 12               GET /api/v1/items HTTP/1.1  173.173.113.51
# 26               GET /api/v1/sales HTTP/1.1   72.181.105.81
# 37              GET /api/v1/stores HTTP/1.1    97.105.19.58
# 17               GET /api/v1/items HTTP/1.1  72.181.113.170
# 41              GET /documentation HTTP/1.1    97.105.19.58
# 4                            GET / HTTP/1.1    97.105.19.58
# 16               GET /api/v1/items HTTP/1.1   72.181.105.81
# 33              GET /api/v1/stores HTTP/1.1  173.173.113.51
# 15               GET /api/v1/items HTTP/1.1  68.201.219.223
# 25               GET /api/v1/sales HTTP/1.1     24.26.242.9
# 47                GET /favicon.ico HTTP/1.1    97.105.19.58
# 9        GET /api/v1//api/v1/items HTTP/1.1    97.105.19.58
# 34              GET /api/v1/stores HTTP/1.1     24.26.242.9
# 13               GET /api/v1/items HTTP/1.1     24.26.242.9
# 21  GET /api/v1/items/api/v1/items HTTP/1.1    97.105.19.58
# 35              GET /api/v1/stores HTTP/1.1   72.181.105.81
# 3                            GET / HTTP/1.1   72.181.105.81
# 32               GET /api/v1/store HTTP/1.1    97.105.19.58
# 22     GET /api/v1/items/next_page HTTP/1.1    97.105.19.58
# 1                            GET / HTTP/1.1  68.201.219.223
# 45                GET /favicon.ico HTTP/1.1   72.181.105.81
# 46                GET /favicon.ico HTTP/1.1  72.181.113.170
# 38                GET /api/v1items HTTP/1.1   72.181.105.81
# 36              GET /api/v1/stores HTTP/1.1  72.181.113.170
# 2                            GET / HTTP/1.1   70.121.214.34
# 39              GET /documentation HTTP/1.1  68.201.219.223
# 40              GET /documentation HTTP/1.1   72.181.105.81
# 42                GET /favicon.ico HTTP/1.1    35.174.209.2
# 43                GET /favicon.ico HTTP/1.1   52.90.165.200
# 44                GET /favicon.ico HTTP/1.1   54.145.52.184
# 14               GET /api/v1/items HTTP/1.1  35.175.171.137
# 31               GET /api/v1/sales/HTTP/1.1    97.105.19.58
# 5              GET /api/V1/HiZach! HTTP/1.1    97.105.19.58
# 30               GET /api/v1/sales/HTTP/1.1   97.105.15.120
# 29              GET /api/v1/sales/ HTTP/1.1    97.105.19.58
# 6                     GET /api/v1/ HTTP/1.1   54.172.14.223
# 7                     GET /api/v1/ HTTP/1.1   72.181.105.81
# 8                     GET /api/v1/ HTTP/1.1    97.105.19.58
# 23          GET /api/v1/itemsitems HTTP/1.1    97.105.19.58
# 20  GET /api/v1/items/api/v1/items HTTP/1.1  68.201.219.223
# 19        GET /api/v1/items&page=0 HTTP/1.1    97.105.19.58
# 10   GET /api/v1/I_DIDNT_DO_IT!!!! HTTP/1.1    97.105.19.58
# 11         GET /api/v1/helloclass! HTTP/1.1    97.105.19.58
# 0                            GET / HTTP/1.1  35.175.171.137
#
#     proba_status_given_req_meth  req_meth_count
# 28                     0.878757            6110
# 24                     0.065152             453
# 18                     0.649755             397
# 27                     0.041852             291
# 12                     0.188216             115
# 26                     0.013376              93
# 37                     0.692982              79
# 17                     0.090016              55
# 41                     0.964286              54
# 4                      0.872727              48
# 16                     0.049100              30
# 33                     0.228070              26
# 15                     0.014730               9
# 25                     0.000863               6
# 47                     0.500000               6
# 9                      1.000000               6
# 34                     0.043860               5
# 13                     0.006547               4
# 21                     0.750000               3
# 35                     0.026316               3
# 3                      0.054545               3
# 32                     1.000000               2
# 22                     1.000000               2
# 1                      0.036364               2
# 45                     0.166667               2
# 46                     0.083333               1
# 38                     1.000000               1
# 36                     0.008772               1
# 2                      0.018182               1
# 39                     0.017857               1
# 40                     0.017857               1
# 42                     0.083333               1
# 43                     0.083333               1
# 44                     0.083333               1
# 14                     0.001637               1
# 31                     0.500000               1
# 5                      1.000000               1
# 30                     0.500000               1
# 29                     1.000000               1
# 6                      0.333333               1
# 7                      0.333333               1
# 8                      0.333333               1
# 23                     1.000000               1
# 20                     0.250000               1
# 19                     1.000000               1
# 10                     1.000000               1
# 11                     1.000000               1
# 0                      0.018182               1

# %%
train = train.reset_index().merge(req_meth_ip, on=['ip', 'request_method'], how='left').fillna(value=0).set_index('timestamp')

# %%
train.head()
# Out:
#                                        ip               request_method  \
# timestamp
# 2019-04-16 22:38:17+00:00    97.105.19.58   GET /api/v1/sales HTTP/1.1
# 2019-04-16 21:09:31+00:00    97.105.19.58   GET /api/v1/sales HTTP/1.1
# 2019-04-17 04:11:16+00:00  173.173.113.51  GET /api/v1/stores HTTP/1.1
# 2019-04-16 19:49:43+00:00    97.105.19.58    GET /favicon.ico HTTP/1.1
# 2019-04-16 19:54:58+00:00    97.105.19.58   GET /api/v1/sales HTTP/1.1
#
#                            status    size  \
# timestamp
# 2019-04-16 22:38:17+00:00     200  510084
# 2019-04-16 21:09:31+00:00     200  510082
# 2019-04-17 04:11:16+00:00     200    1328
# 2019-04-16 19:49:43+00:00     200     162
# 2019-04-16 19:54:58+00:00     200  494819
#
#                                                                  destination  \
# timestamp
# 2019-04-16 22:38:17+00:00                                                  0
# 2019-04-16 21:09:31+00:00                                                  0
# 2019-04-17 04:11:16+00:00                                                  0
# 2019-04-16 19:49:43+00:00  https://python.zach.lol/api/v1//api/v1/items?p...
# 2019-04-16 19:54:58+00:00                                                  0
#
#                                                                request_agent  \
# timestamp
# 2019-04-16 22:38:17+00:00                             python-requests/2.21.0
# 2019-04-16 21:09:31+00:00                             python-requests/2.21.0
# 2019-04-17 04:11:16+00:00                             python-requests/2.21.0
# 2019-04-16 19:49:43+00:00  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 19:54:58+00:00                             python-requests/2.20.1
#
#                             size_mb  ip_proba  proba_status_given_ip  \
# timestamp
# 2019-04-16 22:38:17+00:00  0.486454  0.858595               0.999119
# 2019-04-16 21:09:31+00:00  0.486452  0.858595               0.999119
# 2019-04-17 04:11:16+00:00  0.001266  0.075784               1.000286
# 2019-04-16 19:49:43+00:00  0.000154  0.858595               0.999119
# 2019-04-16 19:54:58+00:00  0.471896  0.858595               0.999119
#
#                            ip_status_count  req_meth_proba  \
# timestamp
# 2019-04-16 22:38:17+00:00          11984.0        0.888335
# 2019-04-16 21:09:31+00:00          11984.0        0.888335
# 2019-04-17 04:11:16+00:00           1059.0        0.014565
# 2019-04-16 19:49:43+00:00          11984.0        0.001533
# 2019-04-16 19:54:58+00:00          11984.0        0.888335
#
#                            proba_status_given_req_meth  req_meth_count
# timestamp
# 2019-04-16 22:38:17+00:00                     0.878757            6110
# 2019-04-16 21:09:31+00:00                     0.878757            6110
# 2019-04-17 04:11:16+00:00                     0.228070              26
# 2019-04-16 19:49:43+00:00                     0.500000               6
# 2019-04-16 19:54:58+00:00                     0.878757            6110

# %%
plt.title("Probability of seeing a request method given an IP given the probability of seeing that request")
plt.xlabel("Probability of seeing request method given the IP")
plt.ylabel("Probabiliy of seeing request method")
plt.scatter(train.proba_status_given_req_meth, train.req_meth_proba)
